# %% [markdown]
# ## Q:如何合併不同張圖?
#
# ## A:可使用matplotlib

# %%
import matplotlib.pyplot as plt

plt.figure() # 建窗口

# %%
plt.subplot(2,1,1)       # 併圖的位置(行，列，第幾個圖)
plt.plot([0,10],[0,100]) # 圖的XY軸

plt.subplot(212)
plt.plot([0,50],[0,10])

plt.show()  # 展示
